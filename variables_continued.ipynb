# %% [markdown]
# ## print helloworld

# %%
S= int(input())
E= int(input())
W= int(input())
fah=S
while fah<=E:
    c=(fah-32)*(5/9)
    #print(str(fah)+" "+str(int(c)))
    print(fah , int(c))
    fah=fah+W
# Out:
# 0
# 100
# 20
# 0 -17
# 20 -6
# 40 4
# 60 15
# 80 26
# 100 37

# %%
print("hello")
print("hello")
10

# %% [markdown]
# ## variables

# %%
a =10
b =20

sum=a+b
print(sum)
# Out:
# 30

# %%
ab_cl=10
_ss=2
#12cd=20
# Out:
#   Cell In[6], line 3
#     12cd=20
#      ^
# SyntaxError: invalid decimal literal

# %%
a=10
b=20
multiple=a*b
print("multiple")
# Out:
# multiple

# %% [markdown]
# # assignning different type of data to a variable

# %%
a =10
a =20
a ="hththa"
a
# Out:
# 'hththa'

# %%
a="abs"
print(type(a))
a=10
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>

# %%
x=10
x="abcd"
print(x)
# Out:
# abcd

# %%
x="abcd"
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
a1=23
a2=3.4
a3=4+5j
print(type(a1))
print(type(a2))
print(type(a3))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
a=10
print(id(a))
a=a+1
print(id(a))
a
# Out:
# 2500849107472
# 2500849107504
# 11

# %%
a=1000
b=1000
print(id(a))
print(id(b))
# Out:
# 2500927676624
# 2500929115504

# %%
a=10
id1=id(a)
print(id1)
b=a+2-2
id2=id(b)
print(id2)
# Out:
# 2500849107472
# 2500849107472

# %% [markdown]
# # arithmetic operator

# %%
a=10
b=4
print(a+b)
print(a-b)
# Out:
# 6

# %%
a*b
# Out:
# 40

# %%
a/b        #floating point division
# Out:
# 2.5

# %%
a//b      #integer division
# Out:
# 2

# %%
a**b    # exponentiation
# Out:
# 10000

# %%
a%b    # remainder of dision (modulus )
# Out:
# 2

# %%
2+(3*4)  # 14 or 20
# Out:
# 14

# %%
2*3/4
# Out:
# 1.5

# %%
(2*3) //4  # don't remember the precedence table if you want to compute first 3*2 then putting bracket around it like this (2*3)
# Out:
# 1

# %%
#simple interest
p =100
r=20
t=2
#si =p*r*t//100
#si=t//100 *r*p
si=(p*r*t)/100
print(si)
# Out:
# 40.0

# %%
# fah to celcius conversion
f=100
c =(f-32)*5/9
print(c)
ci=(f-32)*5//9
ci
# Out:
# 37.77777777777778
# 37

# %% [markdown]
# ### input

# %%
#input()
b= ''
print(type(b))
c=int(b)
c
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 4
#       2 b= '3dfg'
#       3 print(type(b))
# ----> 4 c=int(b)
#       5 c
#
# ValueError: invalid literal for int() with base 10: '3dfg'

# %%
# adding of number
a =int(input())
b =int(input())
print(type(a))
s=a+b
s
# Out:
# 23
# 34
# <class 'int'>
# 57

# %%
a=float(input())
type(a)
# Out:
# 3.4
# float

# %%
# fah to celsius conversion 
f= float(input())
c=(f-32)*5/9
c
# Out:
# 98.6
# 37.0

# %%
#  simple  interest 
p = int(input())
r =int(input())
t =int(input())
si=(p*r*t)/100
si
# Out:
# 100
# 12
# 2
# 24.0

# %%
a =int(input())
b= int(input())
c = int(input())
c=(a+b+c)/3
print(c)
# Out:
# 4
# 3
# 6
# 4.333333333333333
