# %% [markdown]
# ### create a list

# %%
li=[]

# %%
li=[1,2,3]
type(li)
# Out:
# list

# %%
type(li)
# Out:
# list

# %%
li=[1,2,]

# %%
li=[1,2,]

# %%
li=[1,2,'Parika',3.4]

# %%
li
# Out:
# [1, 2, 'Parika', 3.4]

# %% [markdown]
# access and change the element in list

# %%
li[3]
# Out:
# 3.4

# %%
li[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 li[4]
#
# IndexError: list index out of range

# %%
li[0]=5

# %%
li
# Out:
# [5, 2, 'Parika', 3.4]

# %%
li[3]='rohan'

# %%
li
# Out:
# [5, 2, 'Parika', 'rohan']

# %% [markdown]
# ### slicing of alist

# %%
li[1:3]
# Out:
# [2, 'Parika']

# %%
li[1:]
# Out:
# [2, 'Parika', 'rohan']

# %%
li[:]
# Out:
# [5, 2, 'Parika', 'rohan']

# %%
li[1:10]
# Out:
# [2, 'Parika', 'rohan']

# %% [markdown]
# ### insert and Append Element in lists

# %%
li.append("Ankush")

# %%
li
# Out:
# [5, 2, 'Parika', 'rohan', 'Ankush']

# %%
li.insert(1,7)

# %%
li
# Out:
# [5, 7, 2, 'Parika', 'rohan', 'Ankush']

# %%
li.insert(6,10)

# %%
li
# Out:
# [5, 7, 2, 'Parika', 'rohan', 'Ankush', 10]

# %%
li.insert(9,13)

# %%
li
# Out:
# [5, 7, 2, 'Parika', 'rohan', 'Ankush', 10, 13]

# %%
li.append([9,10,11])

# %%
li
# Out:
# [5, 7, 2, 'Parika', 'rohan', 'Ankush', 10, 13, [9, 10, 11]]

# %%
li.extend([9,10,11])

# %%
li
# Out:
# [5, 7, 2, 'Parika', 'rohan', 'Ankush', 10, 13, [9, 10, 11], 9, 10, 11]

# %% [markdown]
# ### Remove element of list

# %%
li.remove(2)

# %%
li
# Out:
# [5, 7, 'Parika', 'rohan', 'Ankush', 10, 13, [9, 10, 11], 9, 10, 11]

# %%
li.append(5)

# %%
li
# Out:
# [5, 7, 'Parika', 'rohan', 'Ankush', 10, 13, [9, 10, 11], 9, 10, 11, 5]

# %%
li.remove(5)

# %%
li
# Out:
# [7, 'Parika', 'rohan', 'Ankush', 10, 13, [9, 10, 11], 9, 10, 11, 5]

# %%
li.pop()
# Out:
# 5

# %%
li.remove(6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 li.remove(6)
#
# ValueError: list.remove(x): x not in list

# %%
li
# Out:
# [7, 'Parika', 'rohan', 'Ankush', 10, 13, [9, 10, 11], 9, 10, 11]

# %%
li.pop()
# Out:
# 11

# %%
li
# Out:
# [7, 'Parika', 'rohan', 'Ankush', 10, 13, [9, 10, 11], 9, 10]

# %%
li.remove(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 li.remove(2)
#
# ValueError: list.remove(x): x not in list

# %%
li.pop(2)
# Out:
# 'rohan'

# %%
li
# Out:
# [7, 'Parika', 'Ankush', 10, 13, [9, 10, 11], 9, 10]

# %%
li.pop(18)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 li.pop(18)
#
# IndexError: pop index out of range

# %%
len(li)
# Out:
# 8
