# %%
def revrese_l(li):
    length=len(li)
    for i in range(len//2):
        li[i],li[length-i-1]=li[length-i-1],li[i]
li=[1,2,3,4,5,6]
reverse_l(li)
print(li)
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
def revrese_l(li):
    length=len(li)
    for i in range(len//2):
        li[i],li[-i-1]=li[-i-1],li[i]
li=[1,2,3,4,5,6]
reverse_l(li)
print(li)
# Out:
# [6, 5, 4, 3, 2, 1]

# %%
li[:1:-1]
# Out:
# [1, 2, 3, 4]

# %%
li[6::-1]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
li[::-1]
# Out:
# [1, 2, 3, 4, 5, 6]
