# %%
start=int(input())
end= int(input())
step= int(input())

while start<=end:
    cel = (start-32)*(5/9)
    print(start, int(cel))
    start +=step
# Out:
# 0
# 100
# 20
# 0 -17
# 20 -6
# 40 4
# 60 15
# 80 26
# 100 37

# %%
def printTable(start,end,step):
    while True:
        c=0
        if start<=end:
            cel = (start-32)*(5/9)
            print(start, int(cel))
            start +=step
            
        else:
            break


 
s = int(input())
e = int(input())
step = int(input())
print(printTable(s,e,step))
# Out:
# 0
# 100
# 20
# 0 -17
# 20 -6
# 40 4
# 60 15
# 80 26
# 100 37
# None
