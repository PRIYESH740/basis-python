# %%
n=int(input())
for i in range(n,0,-1):
    for j in range(n,i-1,-1):
        print(j,end='')
        
    for j in range(1,2*i-1,1):
        print(i,end='')
        
    for j in range(i+1,n+1,1):
        print(j,end='')
        
    print()
    
for i in range(2,n+1,1):
    for j in range(n,i-1,-1):
        print(j,end='')
        
    for j in range(1,2*i-1,1):
        print(i,end='')
        
    for j in range(i+1,n+1,1):
        print(j,end='')
        
    print()
# Out:
# 3
# 33333
# 32223
# 32123
# 32223
# 33333

# %% [markdown]
# ### fibonacci member

# %%
n=int(input())
a=0
b=1
if b==n:
    return b
elif

# %%
n=int(input())
for i in range(1,2,1):
    for j in range(1,n+1,1):
        print(j,end=' ')
    print()
        
    for j in range(2*n+i,2*n+n+1,1):
        print(j,end=' ')
    print()
        
    for j in range(n*(n-1)+i,n*(n-1)+n+1,1):
        print(j,end=' ')
    print()
    if n>=5:
        for j in range(n*(n-2)+1,n*(n-2)+n+1,1):
            print(j,end=' ')
        print()
    
    for j in range(n+1,n+n+1,1):
        print(j,end=' ')
# Out:
# 5
# 1 2 3 4 5
# 11 12 13 14 15
# 21 22 23 24 25
# 16 17 18 19 20
# 6 7 8 9 10

# %%
n = int(input())
upper = int(n/2)+1
lower = n - upper

for i in range(0, upper):
    if i != 0:
        i = i + i
    start = n*i + 1
    end = start + n

    for j in range(start, end):
        print(j, end =" ")
    print()

k
for i in range(0, lower):
    if(n%2 == 0):
        start_i_lower -= 1

    start = n*(start_i_lower-1) + 1
    end = start + n

    for j in range(1, n+1):
        print(j+n, end =" ")

    print()
# Out:
# 5
# 1 2 3 4 5
# 11 12 13 14 15
# 21 22 23 24 25
# 6 7 8 9 10
# 6 7 8 9 10

# %%
n = int(input( ))
P = 1
for i in range(1, n + 1):
    for j in range(P, P + n):
        print(j, end=" ")
    print()
    if i == ((n + 1)//2):
        if (n % 2) != 0:
            P = n*(n - 2) + 1
        else:
            P = n * (n - 1) + 1
    elif i > ((n + 1) // 2):
        P = P - 2 * n
    else:
        P = P + 2 * n
# Out:
# 5
# 1 2 3 4 5
# 11 12 13 14 15
# 21 22 23 24 25
# 16 17 18 19 20
# 6 7 8 9 10

# %%
n =int(input())
r=int(input())
n_fact=1
for i in range(1,n+1):
    n_fact=n_fact*i
    
r_fact=1
for i in range(1,r+1):
    r_fact=r_fact*i
    
n_r_fact=1
for i in range(1,n-r+1):
    n_r_fact=n_r_fact*i
    
ans=n_fact/(r_fact*n_r_fact)
print(ans)
# Out:
# 4
# 2
# 6.0

# %%
def fact(n):
    n_fact=1
    for i in range(1,n+1):
        n_fact=n_fact*i
    return n_fact

# %%
fact(4)
# Out:
# 24

# %%
n =int(input())
r=int(input())
n_fact=fact(n)
r_fact=fact(r)
n_r_fact=fact(n-r)
ans=n_fact//(r_fact*n_r_fact)
print(ans)
# Out:
# 4
# 3
# 4

# %%
def isprime(n):
    for d in range(2,n):
        if (n%d==0):
            break
            
        else:
             return True
        return False

# %%
isprime(11)
# Out:
# True

# %%
# print all print number from to 2 to n

def isprime(n):
    for d in range(2,n):
        if (n%d==0):
            break
            
        else:
             return True
        return False
def primenum(n):
    for k in range(1,n+1):
    #for d in range(2,n+1):
        #if k%d==0:
        
        is_k_prime=isprime(k)
        if (is_k_prime):
            print(k)

# %%
primenum(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 primenum(20)
#
# Cell In[3], line 8, in primenum(n)
#       3 def primenum(n):
#       4     for k in range(1,n+1):
#       5     #for d in range(2,n+1):
#       6         #if k%d==0:
# ----> 8         is_k_prime=isprime(k)
#       9         if (is_k_prime):
#      10             print(k)
#
# NameError: name 'isprime' is not defined

# %%
def ncr(n,r):
    n_fact=fact(n)
    r_fact=fact(r)
    n_r_fact=fact(n-r)
    ans=n_fact//(r_fact*n_r_fact)
    print(ans)

# %%
ncr(5,2)
# Out:
# 10

# %%
def func(a):
    a = a + 10
    return a
a = 5
func(a)
print(a)
# Out:
# 5

# %%
def square(a):
    ans  = a*a
    return  ans

a = 4
a = square(a)
print(a)
# Out:
# 16

# %%
a1 =10    # golbal variable 
def f1():
    b1 =12 #local variable
    print(b1) 
print(a1)
f1()
# can not print local variables outside the function print(b1)
# Out:
# 10
# 12
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       5 print(a1)
#       6 f1()
# ----> 7 print(b1)
#
# NameError: name 'b1' is not defined

# %%
a2 =10    # golbal variable 
def f2():
    b2 =12 #local variable
    print(b2) 
    print(a2)
    
    
print(a2)
f2()
# Out:
# 10
# 12
# 10

# %%
# you can access any global variable defined before the function call
def f3():
    b3 =12 #local variable
    print(b3)
    print(a3)
    print(c3)
a3 =10    # golbal variable
print(a3)
f3()
c3 =20
# Out:
# 10
# 12
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 8
#       6 a3 =10    # golbal variable
#       7 print(a3)
# ----> 8 f3()
#       9 c3 =20
#
# Cell In[9], line 5, in f3()
#       3 print(b3)
#       4 print(a3)
# ----> 5 print(c3)
#
# NameError: name 'c3' is not defined

# %%
a4 =13
def f4():
    a4=12
    print(a4)
    print(id(a4))
print(a4)
f4()
print(a4)
print(id(a4))
# Out:
# 13
# 12
# 1889581531728
# 13
# 1889581531760

# %%
a4 =13
def f4():
    global a4
    a4=12
    print(a4)
    print(id(a4))
print(a4)
f4()
print(a4)
print(id(a4))
# Out:
# 13
# 12
# 1889581531728
# 12
# 1889581531728

# %%
def f():
    b=10
    return b
x=f()
print(x)
# Out:
# 10

# %%
a = 14
def f():
    a = 12
    return a
a = f()
print(a)
# Out:
# 12

# %%
def f(n):
    print(n)
    
f(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 4
#       1 def f(n):
#       2     print(n)
# ----> 4 f(2,3)
#
# TypeError: f() takes 1 positional argument but 2 were given

# %%
def sum(a, b,c=0):
    print(c)
    return a+b+c
print(sum(2,3,4))
print(sum(2,3))
# Out:
# 4
# 9
# 0
# 5

# %%
def f(a=0,b,c):
    return a+b+c
f(1,2)
# Out:
#   Cell In[20], line 1
#     def f(a=0,b,c):
#               ^
# SyntaxError: non-default argument follows default argument

# %%
def f1(a,b,c=2,d=0):
    return a+b+c+d

print(f1(2,3,4,5))
print(f1(3,4))
print(f1(2,3,5))

print(f1(2,3,d=3))
# Out:
# 14
# 9
# 10
# 10

# %%
def f(a=0,d=10,b,c):
    return a+b+c
f(1,2,4)
