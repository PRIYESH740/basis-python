# %%
li=[1,2,"Parikh",9,10,11,"Ankush"]

# %%
print(li.index(2))
# Out:
# 1

# %%
li
# Out:
# [1, 2, 'Parikh', 9, 10, 11, 'Ankush']

# %%
for i in range(len(li)):
    print(li[i])
# Out:
# 1
# 2
# Parikh
# 9
# 10
# 11
# Ankush

# %%
for i in range(2,len(li)):
    print(li[i])
# Out:
# Parikh
# 9
# 10
# 11
# Ankush

# %%
for i in li:
    print(i)
# Out:
# 1
# 2
# Parikh
# 9
# 10
# 11
# Ankush

# %%
for i in li[2:]:
    print(i)
# Out:
# Parikh
# 9
# 10
# 11
# Ankush

# %%
for i in li[2:4]:
    print(i)
# Out:
# Parikh
# 9

# %% [markdown]
# ### negative indexing and sequences

# %% [markdown]
# ### negative indexing

# %%
li=[1,2,3,4,5]

# %%
li[0]
# Out:
# 1

# %%
li[-1]
# Out:
# 5

# %%
li[-3]
# Out:
# 3

# %%
li[-7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 li[-7]
#
# IndexError: list index out of range

# %% [markdown]
# ###Sequencing in list

# %%
li
# Out:
# [1, 2, 3, 4, 5]

# %%
li[1:5:1]
# Out:
# [2, 3, 4, 5]

# %%
li[1:3:1]
# Out:
# [2, 3]

# %%
li[1:5:2]
# Out:
# [2, 4]

# %%
li[1:]
# Out:
# [2, 3, 4, 5]

# %%
li[1::2]
# Out:
# [2, 4]

# %%
li[:3]  #default step is 1.
# Out:
# [1, 2, 3]

# %%
li[-1:]
# Out:
# [5]

# %%
li[-3:-1]
# Out:
# [3, 4]
